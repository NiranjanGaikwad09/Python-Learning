# %% [markdown]
# # String

# %% [raw]
# String is sequence of character often enclosed in single('') , double("") , Triple("""_""")

# %% [markdown]
# ## Charateristics

# %% [raw]
# String is ordered - Every Charecter has a index - index starts with 0
#
# String is INMUTABLE - Once created u cannot change / modify individual character of it
#
# String can be Iterated - Can loop through each character of string

# %%
a = 'Niranjan'
b = "Idli"
c = """azsxdcfgvbh
jnytfrdfc"""

print(c)
# Out:
# azsxdcfgvbh
# jnytfrdfc

# %% [markdown]
# ### Indexing

# %% [markdown]
# ## Positive

# %%
str1 = "Python"

len(str1)
# Out:
# 6

# %%
str1 = "Python"
print(str1[0])
# Out:
# P

# %%
print("index 0 : " , str1[0])
print("index 1 : " ,str1[1])
print("index 2 : " ,str1[2])
print("index 3 : " ,str1[3])
print("index 4 : " ,str1[4])
print("index 5 : " ,str1[5])
# Out:
# index 0 :  P
# index 1 :  y
# index 2 :  t
# index 3 :  h
# index 4 :  o
# index 5 :  n

# %%
str2 = "idli wada"
# it counts empty spaces as well

length = len(str2)
print(length)
# Out:
# 9

# %%
print("index 0 : " , str2[0])
print("index 1 : " , str2[1])
print("index 2 : " , str2[2])
print("index 3 : " , str2[3])
print("index 4 : " , str2[4])
print("index 5 : " , str2[5])
print("index 6 : " , str2[6])
print("index 7 : " , str2[7])
print("index 8 : " , str2[8])

# last index of string = Total length - 1
# Out:
# index 0 :  i
# index 1 :  d
# index 2 :  l
# index 3 :  i
# index 4 :
# index 5 :  w
# index 6 :  a
# index 7 :  d
# index 8 :  a

# %% [raw]
# str3 = "Niraj"
# length = 5 --------- index = 5 - 1
# Positive index = 0 = N , 1 = i , 2 = r , 3 = a , 4 = j

# %% [markdown]
# ## Negetive

# %% [raw]
# str4 = "Python"
# # last char will be given -1 index and then -2 ,-3 ,-4 ,-5 ,-6 till the last char (starts from right to left)

# %% [raw]
# IN -ve index = no of char - no of index

# %%
str4 = 'Python'

print("index -1" , str4[-1])
print("index -2" , str4[-2])
print("index -3" , str4[-3])
print("index -4" , str4[-4])
print("index -5" , str4[-5])
print("index -6" , str4[-6])
# Out:
# index -1 n
# index -2 o
# index -3 h
# index -4 t
# index -5 y
# index -6 P

# %% [markdown]
# ## Slicing

# %% [markdown]
# ### Positive Slicing

# %%
str1 = "Niranjan"

str1[2:5]
# Out:
# 'ran'

# %% [raw]
# str_name[start_index : end_index]    ---- in +VE slicing does not include the end_index
#
# if 'start_index' not given : default index starts at 0th index
#
# default index ends at len(string_name)

# %%
str1[0:3]
# Out:
# 'Nir'

# %%
str1[1:6]
# Out:
# 'iranj'

# %%
str1[1: ]
# if end index is not given it will go till the end
# Out:
# 'iranjan'

# %%
str1[: 5]
# if start index is not given it will start at 0th index
# Out:
# 'Niran'

# %%
text = """Machine learning (ML) is a type of artificial intelligence (AI) that allows software 
applications to become more accurate at predicting outcomes without being explicitly programmed to do so. 
Machine learning algorithms use historical data as input to predict new output values."""

# %%
len(text)
# Out:
# 279

# %%
text[100:200]
# Out:
# 'o become more accurate at predicting outcomes without being explicitly programmed to do so. \nMachine'

# %%
len(text[100:200])
# Out:
# 100

# %%
text[:5]
# Out:
# 'Machi'

# %%
text[10 :]
# Out:
# 'arning (ML) is a type of artificial intelligence (AI) that allows software \napplications to become more accurate at predicting outcomes without being explicitly programmed to do so. \nMachine learning algorithms use historical data as input to predict new output values.'

# %%
text2 = "Machine"

len(text2)

string = text2[0:3]
print(string)

# 0 - 3 = 3 no of char ------------ 0 , 1 , 3
# Out:
# Mac

# %%
txt = 'Niranjan'
l = len(txt[1: 5])
print(l)
# Out:
# 4

# %%
txt = 'Machine Learning'

l = txt[0:5]
print(l)
# Out:
# Machi

# %%
text2[1:5]
# Out:
# 'achi'

# %%
text2[:]
# If no end or start index is given THEN Entire string will be returned
# Out:
# 'Machine'

# %%
text3 = "Machine"
text[0:7:2]

# [start : end : steps]

# %% [raw]
# start → index where slicing starts. Here, 0 → 'M'
#
# end → index where slicing stops. Here, 7 → stops before index 7
#
# step → how many steps to jump after each character. Here, 2 → pick every 2nd character
#
# 0 = M
# 2 = c
# 4 = i
# 6 = e
# ________________________________
#
# M A C H I N E
# 0 1 2 3 4 5 6
#
# starts at 0 index = M
# 0+2 = 2
#
# index 2 = c
# 2=2 = 4
#
# index 4 = I
# 4+2 = 6
#
# index 6 = E

# %%
text3[1: : 2]

# index 1 = a 
# 1+2 = 3

# index 3 = h
# 3+2 = 5 

# index 5 = n
# 5+2 = 7

# len(text3) = 6 
# So stops here

# %% [markdown]
# ### Negetive Slicing

# %% [raw]
# str_name[start_index : end_index]
#
# does not include chat at the end_index
#
# if start_index is not given - [len(str_name): end_index]
#
# if end_index is not given - [start_index : -1]

# %%
str1 = "Niranjan"


str1[ : -1]

# %% [raw]
# N     -8
# I     -7
# R     -6
# A     -5
# N     -4
# J     -3
# A     -2
# N     -1

# %%
str1[ -5: ]

# %%
str1 = "Niranjan Idli"

str1[-11 : -2 : 2]

# %% [raw]
# N -13
# I -12
# R -11
# A -10
# N -9
# J -8
# A -7
# N -6
#   -5
# I -4
# D -3
# L -2
# I -1

# %% [raw]
# -11 = r
#
# -11 + 2 = -9
#
# index -9 = n
# -9 + 2 = -7
#
# index -7 = a
# -7 + 2 = -5
#
# index -5 = ' '
# -5 + 2 = -3
#
# index - 3 = d
# -3 + 2 = -1
#
# end_index = -2(process ends here)

# %%
str1 = "Python"

str1[-6 : -1 : 2]
# Out:
# 'Pto'

# %%
str1[ len(str1): -1 : 2]

# %% [raw]
# returns nothing
#
# because
#
# py is tryng to go from index 6 to right
# it cannot go past because the step is +ve

# %%
len(str1)

# %%
str1[0 : len(str1) : 2]

# starts at 0th index 
# takes steps = +2 
# till len(str1)

# %% [markdown]
# # Reversing String

# %% [markdown]
# ### -Ve indexing

# %%
str = 'PYTHON'

# %% [raw]
# POSITIVE INDEX
#
# P-0
# Y-1
# T-2
# H-3
# O-4
# N-5

# %%
NEGETIVE INDEX 

P= -1
Y= -2
T= -3
H= -4
O= -5
N= -6

# %%
str[: : -1]

# %%
str[-1 : : -1]

# %%
str[ len(str) : -1]

# %%
str[ : : -1]

# %%
str[4:-6]
str[-3 : 1]

# %% [markdown]
# ### reversed() + join()

# %%
new_string = "".join(reversed("String_name"))

# %%
a = "MACHINE"

rev_a = "".join(reversed(a))

print(rev_a)

# %%
b = 'Python'

c = "".join(reversed(b))

print(c)

# %% [markdown]
# ### Using For Loop

# %%
a = "Machine"

rev = ""

for char in a :
    rev = char + rev

print(rev)

# %%
str = "Niranjan"

rev = ""

for c in str :
    rev = c + rev

print(rev)

# %% [markdown]
# # Test

# %%
s = "Python"
print(s[:3])

# %%
s = "Machine"
print(s[:-3])

# %%
s = "Machine"
print(s[-1:-5:-1])

# %%
s = "Programming"
print(s[0:10:2])

# %%
s = "Programming"
print(s[1:9:3])
#rrm

# %%
s = "Programming"
print(s[::-1])
# reverse

# %%
s = "Niranjan"
print(s[7:3:-1])

# %%
s = "niranjan"

print(s[7:2:-1])

# %% [markdown]
# # All Methods

# %%
a = "Niranjan"
print(a.lower())
# Out:
# niranjan

# %%
a.upper()
# Out:
# 'NIRANJAN'

# %%
txt = "Niranjan"

txt.casefold()
# 'casefold()' is used to lowercase more agressively - best for international text comparison
# Out:
# 'niranssn'

# %% [raw]
# .strip()           - spaces from left and right

# %%
text = "   Nira Gaikwad   "

print(text.strip())
# Strip Removes extra spaces from left and right
# Out:
# Nira Gaikwad

# %%
str = "    idli Wada"
print(str.strip())
# Out:
# idli Wada

# %% [raw]
# .lstrip()           - left side

# %%
str = "     Nira Gaik"

str.lstrip()
# Out:
# 'Nira Gaik'

# %% [raw]
# .rStrip()           - right side

# %%
str = 'Nira Gai       '

str.rstrip()
# Out:
# 'Nira Gai'

# %%
text = "***Niranjan****"

print(text.strip("*"))
# Out:
# Niranjan

# %%
txt = "###Nira+++"
print("1st : " , txt)

a = (txt.lstrip("#"))
print("2nd : ",a)

b = (a.rstrip("+"))
print("3rd : " ,b)
# Out:
# 1st :  ###Nira+++
# 2nd :  Nira+++
# 3rd :  Nira

# %% [markdown]
# # .split()       - Converts into List

# %% [raw]
# splits string from left and right into list

# %%
a = "Niranjan Anil Gaikwad"
b = a.split()

# %%
date = '2010-12-20'
print(date.split("-"))
# Out:
# ['2010', '12', '20']

# %%
type(b)
# Out:
# list

# %% [markdown]
# # rsplit()       - Splits from right

# %%
txt = "file.abc.version.txt"

print(txt.rsplit("." , 1))
# Out:
# ['file.abc.version', 'txt']

# %% [markdown]
# # splitlines()       - Splits string at line breaks

# %%
txt = "Desk\nData Sci\nMl"

print(txt.splitlines())
# Out:
# ['Desk', 'Data Sci', 'Ml']

# %% [markdown]
# # .replace()

# %%
a = "Python"

a.replace('P' , 'L')
# Out:
# 'Lython'

# %% [markdown]
# # Searching & checking presence

# %% [raw]
# find()          - Returns the index of letter
# count()         - Counts the occurance of letter in string
# startswith()    - Checks if strings starts with or not - if yes returns True
# endswith()

# %%
a = 'Niranjan'

a.find('r')
# Out:
# 2

# %%
a = "Shraddha didi"

print("Occurance of 'B' is : " , a.count('d'))
# Out:
# Occurance of 'B' is :  4

# %%
a = 'Shraddha'

print(a.startswith('S'))
# Out:
# True

# %%
a = 'Shraddha'

print(a.startswith('s'))
# Python is case sensitive
# Out:
# False

# %%
a = 'Duddi'
a.endswith('i')
# Out:
# True

# %%
a = 'Duddi'
a.endswith('s')
# Out:
# False

# %% [markdown]
# # Validation methods (very common in interviews)

# %% [raw]
# isalpha()        - Is alphabate or not
# isdigit()        - Is digit or not
# isalnum()        - Is Numeric or not
# isspace()

# %%
a = 'dfghjdfghj'
a.isalpha()
# Out:
# True

# %%
a.isdigit()
# Out:
# False

# %%
b = '345678'
b.isdigit()
# Out:
# True

# %% [raw]
# isalnum()    - Used to check if string contains alphabets + numbers only

# %%
c = 'Niranjan123'

c.isalnum()
# Out:
# True

# %%
d = '       '

d.isspace()
# Out:
# True

# %%
e = '   a '

e.isspace()
# Out:
# False

# %% [markdown]
# # join()
#
# Used to combine a 'list' of strings into one string using a separator.

# %%
a = ['Shraddha' , 'Anil' , 'Gaikwad']

b = " ".join(a)
print(b)
# Out:
# Shraddha Anil Gaikwad

# %%
b = ['Shraddha' , 'Didi' , 'Nini']

b = " , ".join(b)
b
# Out:
# 'Shraddha , Didi , Nini'

# %% [markdown]
# # encode()
#
# Used to convert string into bytes (needed for files, web data, ML pipelines).

# %%
text = "data science"

encoded = text.encode()
print(encoded)
# Out:
# b'data science'

# %%
type(encoded)
# Out:
# bytes
