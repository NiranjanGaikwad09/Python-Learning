# %% [markdown]
# # Lamda Function

# %% [raw]
# 1. Lamda function is Anonymous Function >> One without name
# 2. Lamda Function is defined using keword 'lamda'
# 3. Lamda is reserved keyword in Python
# 4. No need to use return statement or def keyword
# 5. Higher order function >> Function takes argument as another function

# %% [markdown]
# ## Syntax

# %% [raw]
# lamda arguments : expression
#
# arguments >> Multiple
# expressions >> Single

# %%
def fib(n):
    print("Fibonacci")
    return False
fib(18)
# Out:
# Fibonacci
# False

# %%
def cube(n):
    return n ** 3
cube(3)
# Out:
# 27

# %%
cube(5)
# Out:
# 125

# %%
cube(9)
# Out:
# 729

# %%
def Multi(a , b):
    return a*b

Multi(10 , 9)
# Out:
# 90

# %%
def multi(x, y):
    multi = x *y
    return multi

multi(10 , 3)
# Out:
# 30

# %%
(lambda a , b : a * b) (11 , 2)
# Out:
# 22

# %%
(lambda a , b : a+b) (10 , 20 )
# Out:
# 30

# %%
(lambda a , b  : a*b) (10 , 11 , 12)

# Error : >> <lambda>() takes 2 positional arguments but 3 were given
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 (lambda a , b  : a*b) (10 , 11 , 12)
#
# TypeError: <lambda>() takes 2 positional arguments but 3 were given

# %%
(lambda  a, b : a * b ) (10)

# Error : >> <lambda>() missing 1 required positional argument: 'b'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 (lambda  a, b : a * b ) (10)
#
# TypeError: <lambda>() missing 1 required positional argument: 'b'

# %%
mul = (lambda a , b : a * b) (10 , 3)
mul
# Out:
# 30

# %%
add_3 = (lambda a , b , c : a+b+c) (10 , 5 , 15)
add_3
# Out:
# 30

# %%
add_3 = lambda a , b , c : a + b + c
add_3(10 , 15 , 90)
# Out:
# 115

# %%
add_2 = lambda a , b : a+b
add_2(10 , 3)
# Out:
# 13

# %%
mul = lambda a , b : a*b
mul(10 , 5)
# Out:
# 50

# %%
print_100 = lambda a : 100
print(print_100(2))
# Out:
# 100

# %%
x = lambda a : "Python"

print(x(2))
print(x(5))
# Out:
# Python
# Python

# %%
x = lambda a : "Idli Wada"

print(x(1))
print(x(8))
print(x(1))
print(x(8))
# Out:
# Idli Wada
# Idli Wada
# Idli Wada
# Idli Wada

# %%
x = lambda a : a ** 2

print(x(10))
print(x(5))
print(x(7))
# Out:
# 100
# 25
# 49

# %%
x_100 = lambda a : a +100

print(x_100(20))
print(x_100(30))
print(x_100(40))
# Out:
# 120
# 130
# 140

# %%
x_y_multi = lambda x , y : x * y

print(x_y_multi(10 , 3))
print(x_y_multi(20 , 3))
print(x_y_multi(30 , 3))
# Out:
# 30
# 60
# 90

# %%
x_y_multi(10 , 20)
# Out:
# 200

# %%
sqr = lambda a : a ** 2

print(sqr(9))
print(sqr(11))
# Out:
# 81
# 121

# %%
(lambda a , b , c : (a+b+c)/3)(4 , 5, 6)
# Out:
# 5.0

# %%
avg = (lambda a , b , c : (a+b+c)/3)(10 , 15 , 14)
avg
# Out:
# 13.0

# %%
(lambda a , b , c: (a+b+c)/3)(10 , 15 , 20)
# Out:
# 15.0

# %%
avg = (lambda a , b , c : (a+b+c)/3)(10 , 20 , 33)
avg
# Out:
# 21.0

# %%
avg = lambda a,b,c : (a+b+c)/3
avg(10 , 20 , 22)
# Out:
# 17.333333333333332

# %%
avg(a=3,b=4,c=5)
# Out:
# 4.0

# %%
avg(c = 10 , a = 31 , b = 90)
# Out:
# 43.666666666666664

# %%
avg(100 , b = 200 , c =90)
# Out:
# 130.0

# %%
avg(100 , a = 89 , c = 90)

# Error : >> <lambda>() got multiple values for argument 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 avg(100 , a = 89 , c = 90)
#
# TypeError: <lambda>() got multiple values for argument 'a'

# %%
lambda n1 , n2 , n3 , n4 , n5 : sum ([n1 , n2 , n3 , n4 , n5])/5
# Out:
# <function __main__.<lambda>(n1, n2, n3, n4, n5)>

# %%
avg = lambda n1 , n2 , n3 , n4 , n5 : sum ([n1 , n2 , n3 , n4 , n5])/5
avg(10 , 21 , 22 , 23 , 41 )
# Out:
# 23.4

# %%
avg(b = 10 , c = 21 , a = 22)
# Out:
# 17.666666666666668

# %%
avg = (lambda a , b , *args : sum(args)/len(args))
avg(1, 2 , 3, 4 , 5, 6)
# Out:
# 4.5

# %%
avg = lambda *args: sum(args) /len(args)
avg(1, 2 , 3 , 4 , 5 , 6)
# Out:
# 3.5

# %%
avg = lambda **kwargs : sum(kwargs.values())/len(kwargs)

avg(a = 10 ,b = 12 , c = 13 , d = 15 ,e =  16)
# Out:
# 13.2

# %%
avg = lambda **kwargs : sum(kwargs.values())/len(kwargs)

avg(a = 10 , b = 23)
# Out:
# 16.5

# %%
avg = lambda **kwargs : sum(kwargs.values())/len(kwargs)
avg(a = 20 , b =20 , c = 23)
# Out:
# 21.0

# %%
test = lambda a, b ,*args, x = 100 , y = 120 , **kwargs : [a, b , args , x , y , kwargs]
test(10 , 21 )
# Out:
# [10, 21, (), 100, 120, {}]

# %%
test = lambda a , b, *args , x =101 , y = 105 , **kwargs : [a , b , args , x , y , kwargs]
test(10 , 12 , 13 , 44 , 676 , 90, x ='python' , y = 'ML')
# Out:
# [10, 12, (13, 44, 676, 90), 'python', 'ML', {}]

# %%
test(10 , 20 , 12 , 78 , x = 'idli' , y = 'wada' , v1 = 100 , v2 = 211 , v3= 90)
# Out:
# [10, 20, (12, 78), 'idli', 'wada', {'v1': 100, 'v2': 211, 'v3': 90}]

# %%
list1 = [10 , 12 , 3 , 34 , 55]
sqr = [i**2 for i in list1]

sqr
# Out:
# [100, 144, 9, 1156, 3025]

# %%
list1 = [1, 2 , 3, 4 , 5 ,6 ,7]
sqr = [i**2 for i in list1]

sqr
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
l1 = range(1 , 10)
for i in l1:
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
sqr = [i**2 for i in l1]
sqr
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
l1 = range(1, 10+1)

sqr =[i**2 for i in l1]
sqr
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
sqr = lambda l1 : [i**2 for i in l1] 
sqr(range(1 , 10+1))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
sqr = lambda l2 : [i ** 2 for i in l2]
sqr([10 , 11 , 12])

# %%
sqr = lambda l2 : [i ** 2 for i in l2]

list2 = [10 ,12 , 13 , 14]
sqr(list2)
# Out:
# [100, 144, 169, 196]

# %%
list2
# Out:
# [10, 12, 13, 14]

# %%
x = lambda s1 : [i for i in s1]
x('Python')
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
for i in 'Niranjan' :
    print(i)
# Out:
# N
# i
# r
# a
# n
# j
# a
# n

# %%
z = lambda s1 : [i for i in s1]
x('Niranjan')
# Out:
# ['N', 'i', 'r', 'a', 'n', 'j', 'a', 'n']

# %%
x = lambda s1 : s1.upper()
x("NiraNjaN")
# Out:
# 'NIRANJAN'

# %%
y = lambda s2 : s2.lower()
y("NiraNjan")
# Out:
# 'niranjan'

# %%
a = lambda txt1 , txt2 : txt1 + txt2
a("Niranjan" , "Gaikwad")
# Out:
# 'NiranjanGaikwad'

# %%
a = lambda t1 , t2 , t3 : t1+t2+t3
a("Niranjan" , " " , "Gaikwad")
# Out:
# 'Niranjan Gaikwad'

# %%
a = lambda t1 , t2 : t1+" "+t2
a("Nira" , "Gaik")
# Out:
# 'Nira Gaik'

# %%
a = lambda t1 : t1*2
a("Nira")
# Out:
# 'NiraNira'

# %%
a = lambda t1 : t1*2
a("Nira ")
# Out:
# 'Nira Nira '
