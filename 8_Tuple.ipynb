# %% [markdown]
# # Tuple

# %% [raw]
# Tuple is Ordered , immutable data type
# used to store collection of multiple data types
# in single variable.
#
#     1. Immutable
#     2. Ordered Datatypes
#     3. Duplicates are allowed
#     4. Encloed in ()
#     5. Comma saperated
#     6. Datatypes : int, float, complex,list , tuple, str, dict,series, df .....

# %%
a = (0 , 89 , 3 , 1 , 80 , 1 , 30)
type(a)
# Out:
# tuple

# %%
len(a)
# Out:
# 7

# %%
a[3]
# Out:
# 1

# %%
list = [10 , 3 , 90 , 77]
list[1] = 'Idli'
list
# Out:
# [10, 'Idli', 90, 77]

# %%
tup = (1 , 40 , 2 , 55)
tup[2] = 'Idli'

# "TypeError: 'tuple' object does not support item assignment"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 tup = (1 , 40 , 2 , 55)
# ----> 2 tup[2] = 'Idli'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = (1 , 30 , 77 , 34)

for item in t1:
    print(item)
# Out:
# 1
# 30
# 77
# 34

# %%
tuple1 = ('MONDAY', 'TUESDAY', 'WEDNESDAY', 'THURSDAY', 'FRIDAY', 'SATURDAY', 'SUNDAY')

days_length_6 = []

for day in tuple1:
    if len(day) == 6:
        days_length_6.append(day)
        
days_length_6
# Out:
# ['MONDAY', 'FRIDAY', 'SUNDAY']

# %%
len(days_length_6)
# Out:
# 3

# %%
type(days_length_6)
# Out:
# list

# %% [markdown]
# # Python Casting

# %%
tup1 = (1 , 2 ,3 , 4 ,5,6 ,7)
tup1.append('iid')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 tup1 = (1 , 2 ,3 , 4 ,5,6 ,7)
# ----> 2 tup1.append('iid')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tuple1 = (2,3,4,5,6,7)

tuple1.append("python")
# 'tuple' object has no attribute 'append'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 tuple1 = (2,3,4,5,6,7)
# ----> 3 tuple1.append("python")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
list1 = list(tuple1)
print(type(list1))
list1
# Out:
# <class 'list'>
# [2, 3, 4, 5, 6, 7]

# %%
list1.append("python")

# %%
tup1 = tuple(list1)
tup1
# Out:
# (2, 3, 4, 5, 6, 7)

# %%
tup1
# Out:
# (2, 3, 4, 5, 6, 7)

# %% [markdown]
# ## INdex

# %% [raw]
# Syntax:
# name_tuple.index(Item)

# %%
tuple1 = (2, 3, 4, 5, 6, 7)

tuple1.index(2)
# Out:
# 0

# %%
tup1 = ('Idli' , 'wada' , 'samber' , 'rmd')

tup1.index('wada')
# Out:
# 1

# %%
tuple1 = (2, 3, 4, 4, 5, 6, 4,4,4)

index_list_4 = [index  for index,value in enumerate(tuple1)   if value == 4]
index_list_4
# Out:
# [2, 3, 6, 7, 8]

# %%
tuple1 = (2, 3, 4, 4, 5, 6, 4,4,4)


for index , value in enumerate(tuple1):
    if value == 4 :
        print(index)
# Out:
# 2
# 3
# 6
# 7
# 8

# %%
tuple1 = (2, 3, 4, 4, 5, 6, 4,4,4)

for i , v in enumerate(tuple1):
    if v == 4:
        print(i)
# Out:
# 2
# 3
# 6
# 7
# 8

# %% [markdown]
# ## Count

# %% [raw]
# Syntax :
#     tuple_name.count(element)
# ## Returns the occurance of one item

# %%
tuple1 = (2, 3, 4, 4, 5, 6, 4,4,4)
tuple1.count(4)
# Out:
# 5

# %% [markdown]
# # Built in Functions

# %% [raw]
# 1. sorted
# 2. reversed
# 3. max
# 4. min
# 5. sum

# %% [markdown]
# ## 1. sorted

# %%
tuple1 = (1 , 8 , 2 , 89 , 4 , 345 , 999)
sorted(tuple1)
# Out:
# [1, 2, 4, 8, 89, 345, 999]

# %%
a = sorted(tuple1)
a
# a >>> list
# Out:
# [1, 2, 4, 8, 89, 345, 999]

# %%
type(a)
# Out:
# list

# %%
a = (1 , 8 , 2 , 89 , 4 , 345 , 999)
b = tuple(sorted(a))
b
# Out:
# (1, 2, 4, 8, 89, 345, 999)

# %%
type(b)
# Out:
# tuple

# %% [markdown]
# ## 2. reversed

# %%
a = (1, 2, 4, 8, 89, 345, 999)

reversed(a)

# %%
a = (1, 2, 4, 8, 89, 345, 999)

b = tuple(reversed(a))
b
# Out:
# (999, 345, 89, 8, 4, 2, 1)

# %%
tuple1 = (999, 345, 89, 8, 4, 2, 1)
a = tuple(reversed(a))
print("Previous Tuple : " , tuple1)
print("Reversed Tuple : " , a)
# Out:
# Previous Tuple :  (999, 345, 89, 8, 4, 2, 1)
# Reversed Tuple :  (1, 2, 4, 8, 89, 345, 999)

# %% [markdown]
# ## 3. max
# ## 4. min
# ## 5. sum

# %%
tuple1 = (99, 345, 89, 8, 4, 2, 1)
max_tuple1 = max(tuple1)
print("Max : " , max_tuple1)
# Out:
# Max :  345

# %%
min_tuple1 = min(tuple1)
print("Min : " , min_tuple1)
# Out:
# Min :  1

# %%
marks = (100 , 89 , 90 , 98 , 89)
sum_marks = sum(marks)
print("sum of marks : " , sum_marks)
# Out:
# sum of marks :  466

# %% [markdown]
# # Methods Of Tuple

# %% [raw]
# count()
# >>>> Returns the number of occurance or element
#
# index()
# >>>> Returns the index of element

# %%
tuple1 = (99, 345, 89,99,  8, 4, 2, 1)
tuple1.count(99)
# Out:
# 2

# %%
tuple1 = (99, 345, 89,99,  8, 4, 2, 1)
tuple1.index(8)
# Out:
# 4
