# %% [markdown]
# # List

# %% [raw]
# list is Collection of items
# we can add any data type in list
# int, float , complex , str , list , tuple , dict , frozenset

# %% [markdown]
# ## Properties

# %% [markdown]
# List is mutable >> Can be changed
#
# list is ordered data type
#
# Duplicates are allowed in List
#
# list is enclosed by [....]
#
# Items in list are saperated by commas

# %%
list = [1 , 11 , 'Nira' , 90]

print(list)
# Out:
# [1, 11, 'Nira', 90]

# %%
type(list)
# Out:
# list

# %%
list2 = [10 , 40 , 90 , 1 , 5 , 5 , 5 , 9 ,9]

list2
# allows duplicate
# Out:
# [10, 40, 90, 1, 5, 5, 5, 9, 9]

# %%
list2[0] = "idli"

# Mutable hence can add / delete any item
list2
# Out:
# ['idli', 40, 90, 1, 5, 5, 5, 9, 9]

# %%
len(list2)
# Out:
# 9

# %%
list3 = ["idli" , 0.90 , 10 , 9+0j , "@" , [2,3,8] , {3 ,1 ,9} , (2,3,0)]

list3
# Out:
# ['idli', 0.9, 10, (9+0j), '@', [2, 3, 8], {1, 3, 9}, (2, 3, 0)]

# %% [markdown]
# ### Indexing

# %% [raw]
# # index will always start at 0th index

# %%
list1 = ['idli' , 'wada' , 8 , 90 , 10]

# %%
print(list1[0])
print(list1[1])
print(list1[2])
print(list1[3])
print(list1[4])
# Out:
# idli
# wada
# 8
# 90
# 10

# %%
list1[-1]
# Out:
# 10

# %%
list1[-4]
# Out:
# 'wada'

# %% [raw]
# list1 +ve index
#
# idli-------0
# wada-------1
# 8-------2
# 90-------3
# 10-------4

# %% [raw]
# list1 -ve Index
#
# idli========-5
# wada======== -4
# 8======== -3
# 90======== -2
# 10======== -1

# %%
list1[-5]
# Out:
# 'idli'

# %% [markdown]
# # Slicing

# %% [raw]
# [start_index (include) : end_index (exclude) : step_size]
#
# [          0           :    len(ver)         :      1    ]

# %% [markdown]
# ### Positive Slicing

# %%
list1[ : ]
# Out:
# ['idli', 'wada', 8, 90, 10]

# %%
list1[ : 3]
# Out:
# ['idli', 'wada', 8]

# %%
list1[0 : 3]
# Out:
# ['idli', 'wada', 8]

# %%
list1[1 : 4]
# Out:
# ['wada', 8, 90]

# %%
list1 [1 : 3]
# Out:
# ['wada', 8]

# %% [markdown]
# ### Negetive Slicing

# %% [raw]
# [start_index (include) : end_index (exclude) : step_size]
#
# [     0    :    len(ver)    :      1    ]

# %%
list1= [10 , 30 , 40 , 11 , 90]

print(list1)
# Out:
# [10, 30, 40, 11, 90]

# %% [raw]
# [10, 30, 40, 11, 90]
#
#  -5  -4  -3  -2  -1

# %%
list1[ -5 : - 2 ]
# Out:
# [10, 30, 40]

# %%
print(list1[-5 : -1])
print(list1[-4 : -3])
print(list1[-5 : -2])
print(list1[-4 : -1])
# Out:
# [10, 30, 40, 11]
# [30]
# [10, 30, 40]
# [30, 40, 11]

# %%
# Out:
# 11

# %%
list1[ : : -1]

# Reverse the list
# Out:
# [10, 30, 40, 11, 90]

# %%
list1[0 : 4 : 1]
# Out:
# [10, 30, 40, 11]

# %%
list1
# Out:
# [10, 30, 40, 11, 90]

# %%
print(list1[2 :  : -1 ])
# Out:
# [40, 30, 10]

# %% [raw]
# at index 2 = 40
#
# index 2 - 1 = 1
#
# at index 1 = 30
#
# index 1 - 1 = 0
#
# at index 0 = 10

# %%
print(list1[-4 : : -1])
# Out:
# [30, 10]

# %% [raw]
# index -4 = 30
# -4 - 1 = -5
#
# index -5 = 10

# %%
print(list1[-1 : -3 : -1])
# Out:
# [90, 11]

# %% [markdown]
# # Access Items Using Loop

# %%
list1 = [10 , 20 , 55 , 56 , 90]
list1
# Out:
# [10, 20, 55, 56, 90, 99, 67]

# %%
for i in list1 :
    print(i)
# Out:
# 10
# 20
# 55
# 56
# 90
# 99
# 67

# %%
list1 = [10 , 20 , 55 , 56 , 90]

for i in list1:
    print(i ** 2)
    # in every iteration value of i * i
# Out:
# 100
# 400
# 3025
# 3136
# 8100
# 9801
# 4489

# %%
list1 = [10 , 20 , 55 , 56 , 90]

for i in list1:
    print(i*i)
# Out:
# 100
# 400
# 3025
# 3136
# 8100
# 9801
# 4489

# %%
list1 = [10 , 20 , 55 , 56 , 90]

for i in list1:
    print(i-1)
# Out:
# 9
# 19
# 54
# 55
# 89

# %%
list1 = [10 , 20 , 55 , 56 , 90]
for i in list1:
    print("hello")

len(list1)
# Out:
# hello
# hello
# hello
# hello
# hello
# 5

# %%
list1 = [10 , 20 , 55 , 56 , 90]

for a in list1 :
    print("Item is : " , a)
# Out:
# Item is :  10
# Item is :  20
# Item is :  55
# Item is :  56
# Item is :  90

# %%
a = [1 , 3 , 5 , 7 , 9 , 90 , 90  , 88]
b = 0

for i in a :
    b += 1
    print(f"Iteration  {b}: {i}")
# Out:
# Iteration  1: 1
# Iteration  2: 3
# Iteration  3: 5
# Iteration  4: 7
# Iteration  5: 9
# Iteration  6: 90
# Iteration  7: 90
# Iteration  8: 88

# %%
a = "PYTHON"

for char in a :
    print(char)
# Out:
# P
# Y
# T
# H
# O
# N

# %%
a = 234567

for no in a :
    print(no)

# int is not iterable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 a = 234567
# ----> 3 for no in a :
#       4     print(no)
#
# TypeError: 'int' object is not iterable

# %%
num = '3456765'

for a in num :
    print(a)
# Out:
# 3
# 4
# 5
# 6
# 7
# 6
# 5

# %%
for i in "idli wada":
    print(i)
# Out:
# i
# d
# l
# i
#
# w
# a
# d
# a

# %% [markdown]
# # Operations

# %%
list1 = ["idli" , 89 , 66 , 1 , 6 , 00]
list1
# Out:
# ['idli', 89, 66, 1, 6, 0]

# %% [markdown]
# ### Acessing element

# %%
list1[0]
# Out:
# 'idli'

# %%
list1[-2]
# Out:
# 6

# %% [markdown]
# ### Change Element

# %%
list1 = ["idli" , 89 , 66 , 1 , 6 , 00]

# %%
list1[0] = "wada"
# list is mutable << Means we can change 
list1
# Out:
# ['wada', 89, 66, 1, 6, 0]

# %%
list1 = [1 , 2 , ('a' , "idli" , 3) , 90]

for value in list1:
    print(value)
# Out:
# 1
# 2
# ('a', 'idli', 3)
# 90

# %% [markdown]
# ### Add elements

# %% [markdown]
# ### .append()

# %% [raw]
#  list_name.append(value) - it adds element at the end

# %%
list1
# Out:
# [1, 2, ('a', 'idli', 3), 90]

# %%
list1.append(9090)
list1
# Out:
# [1, 2, ('a', 'idli', 3), 90, 9090, 9090]

# %% [markdown]
# ### .insert()

# %% [raw]
# list_name.insert(index , value)      - insert value at specific index

# %%
list1.insert(2, 8)
list1
# Out:
# [1, 2, 8, 8, ('a', 'idli', 3), 90, 9090, 9090]

# %% [markdown]
# ### .extend()

# %% [raw]
# list_name.extend([v1 , v2 , v3 , v4])   - Inserts multiple values at end

# %%
list1.extend([6 , 3 , 9])
list1
# Out:
# [1, 2, 8, 8, ('a', 'idli', 3), 90, 9090, 9090, 6, 3, 9]

# %% [markdown]
# ### Remove element

# %%
list1.remove(8)

list1
# Out:
# [2, 8, ('a', 'idli', 3), 90, 9090, 9090, 6, 3, 9]

# %%
list1.pop()
# removes last elemt
list1
# Out:
# [2, 8, ('a', 'idli', 3), 90, 9090, 9090, 6]

# %% [raw]
# list1.pop(index)

# %%
list1.pop(3)
print(list1)
# Out:
# [2, 8, ('a', 'idli', 3), 9090, 9090, 6]

# %% [raw]
# del list_name[index]

# %%
del list1[5]
print(list1)
# Out:
# [2, 8, ('a', 'idli', 3), 9090, 9090]

# %% [raw]
# list_name.clear()
#
# # deletes entire list

# %%
list1.clear()

# %% [markdown]
# # Methods

# %%
list1 = ['Niranja' , 'idli' , 678 , 1 , 90 ]
list1
# Out:
# ['Niranja', 'idli', 678, 1, 90]

# %% [raw]
# .append()    - adds element at last index

# %%
list1.append('pav')
list1
# Out:
# ['Niranja', 'idli', 678, 1, 90, 'pav']

# %% [raw]
# .extend()         - adds multiple element at last index

# %%
list1.extend([2 , 3 , 6])
list1
# Out:
# ['Niranja', 'idli', 678, 1, 90, 'pav', 2, 3, 6, 2, 3, 6]

# %% [raw]
# .insert()         -  insert at specific index .insert(index , 'element')

# %%
list1.insert( 1 , '001')
list1
# Out:
# ['Niranja', '001', '001', 'idli', 678, 1, 90, 'pav', 2, 3, 6, 2, 3, 6]

# %% [raw]
# .remove()

# %%
list1.remove('idli')
list1
# Out:
# ['Niranja', '001', '001', 678, 1, 90, 'pav', 2, 3, 6, 2, 3, 6]

# %%
list1.remove('001')
list1
# Out:
# ['Niranja', 678, 1, 90, 'pav', 2, 3, 6, 2]

# %% [raw]
# .pop()        - removes last element as executed

# %%
list1.pop()
print(list1)
# Out:
# ['Niranja', 678, 1, 90, 'pav', 2, 3, 6]

# %%
list1.pop()
print(list1)
# Out:
# [1, 90, 'pav', 2]

# %% [raw]
# .pop ---------->  .pop(index)

# %%
list1 = ['Niranja', '001', '001', 'idli', 678, 1, 90, 'pav', 2, 3, 6, 2, 3, 6]

# %%
list1.pop(0)
print(list1)
# Out:
# ['001', '001', 'idli', 678, 1, 90, 'pav', 2, 3, 6, 2, 3, 6]

# %% [raw]
# .clear()        - Cleans / emplties up entire list

# %%
list1.clear()

# %%
list1
# Out:
# []

# %%
l1 = ['001', '001', 'idli', 678, 1, 90, 'pav', 2, 3, 6, 2, 3, 6]

# %% [raw]
# index()       - Returns index of item

# %%
l1.index('001')
# Out:
# 0

# %%
l1.index(1)
# Out:
# 4

# %% [raw]
# .count()       - Returns the no of occurance of a item

# %%
l1.count('001')
# Out:
# 2

# %%
l1.count(2)
# Out:
# 2

# %% [raw]
# sort()          - sorts list alpha / numerically

# %%
l2 = [89 , 1 , 2 , 43, 4 , 3.14]

l2.sort()
l2
# Out:
# [1, 2, 3.14, 4, 43, 89]

# %%
l3 = ['idli' , 'air' , 'didi' , 'zero']

l3.sort()
l3
# Out:
# ['air', 'didi', 'idli', 'zero']

# %% [raw]
# .reverse()     - Reverses the list

# %%
list = [1 , 3 , 6 , 'pav' , 90 ]
list.reverse()
list
# Out:
# [90, 'pav', 6, 3, 1]

# %% [raw]
# .copy

# %%
a = [1 , 7 , 89 , 990 , 23 , 799]

b = a.copy()
print(b)
# Out:
# [1, 7, 89, 990, 23, 799]

# %% [markdown]
# # Common built-in functions used with lists

# %% [raw]
# len()
#
# max()
#
# min()
#
# sum()
#
# sorted()
#
# any()
#
# all()

# %%
len(a)
# Out:
# 6

# %%
max(a)
# Out:
# 990

# %%
min(a)
# Out:
# 1

# %%
sum(a)
# Out:
# 1909

# %%
sorted(a)
# Out:
# [1, 7, 23, 89, 799, 990]

# %%
any(a)
# Out:
# True

# %%
all(a)
# Out:
# True
