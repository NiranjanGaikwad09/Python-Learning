# %% [markdown]
# # Functions

# %% [raw]
# FUNCTION >> Block of code which is executed once its called
# FUNCTION >> Block of code
#
# 1. def keyword is used to define a function
# 2. Function Name >> Have to follow identifiers rules (var , func , class_name)
# 3. return statement is Optional

# %%
x , y = 10 , 15

add = x+y
add
# Out:
# 25

# %%
def add_function(x , y , z):
    add = x + y
    return add
    
add_function(10 , 20 , 13)
# Out:
# 30

# %%
def add_func(a1 , a2 , a3):
    
    add2 = a1 + a2 
    add3 = a1 + a2 + a3
    
    #return add3
    return add2

add_func(10 , 11, 12)
# Out:
# 21

# %%
add_function(1, 99, 7)
# Out:
# 100

# %%
def add_func(*a):
    add = sum(a)
    return add
add_func(5.13, 4897 ,23, 333)
# Out:
# 5258.13

# %%
add_func(5, 1 ,78 , 90)
# Out:
# 174

# %%
def add_func(*x):
    add = sum(x)
    return add

add_func(12 , 14 , 88 , 19)
# Out:
# 133

# %% [raw]
# *x means variable-length arguments
# >>>> The function can accept any number of values.

# %%
def add_func(x = 10 , y = 34 , z = 34):
    print(f"x = {x}")
    print(f"y = {y}")
    print(f"z = {z}")
    
    add = x + y + z
    return("Addition : " , add)

add_func()
# Out:
# x = 10
# y = 34
# z = 34
# ('Addition : ', 78)

# %%
add_func(133)
# Out:
# x = 133
# y = 34
# z = 34
# ('Addition : ', 201)

# %% [markdown]
# ### Syntax

# %% [raw]
# def Function_Name(Parameters):  >>>>> Parameters are optional
#     """Docstring : Functionality of function """     >>>> Docstring is Optional
#
#     Statement-1
#     Statement-2
#     Statement-N
#
#     Return(Value)        >>>> Optional
#
# Function_Name(arguements)  >>>> If (Parameters) are given we have to pass the (arguements)

# %%
print("We are learing Python and Data Science")

x = 10 
y = 45

add = x + y
print(f"Addition of {x} and {y}: {add}")

print("Machine Learning")
print("Deep Learning")
print("NLP")
# Out:
# We are learing Python and Data Science
# Addition of 10 and 45: 55
# Machine Learning
# Deep Learning
# NLP

# %%
def My_Func():
    print("Learn - Python , Ds , Big data , data Engineering")
    x = 10 
    y = 13
    add = x + y

    print(f"Addition of {x} and {y} >> {add}")
    print("Machine Learning")
    print("Deep Learning")
    print("NLP")
    print("*  " *20)
    print()

My_Func()
My_Func()
# Out:
# Learn - Python , Ds , Big data , data Engineering
# Addition of 10 and 13 >> 23
# Machine Learning
# Deep Learning
# NLP
# *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
# Learn - Python , Ds , Big data , data Engineering
# Addition of 10 and 13 >> 23
# Machine Learning
# Deep Learning
# NLP
# *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *

# %%
def add_func(a , b , c):
    """ rdqwtywfq dhegdywegd """
    add = a + b + c
    return(f"Addition of {a} , {b} , {c} : {add}")

add_func( 10, 67, 90)
# Out:
# 'Addition of 10 , 67 , 90 : 167'

# %%
print(add_func.__doc__)
# Out:
#  rdqwtywfq dhegdywegd

# %%
def add_3_variable(x = 11 , y = 36 , z = 89):
    
    """Adding 3 Variables"""
    add = x + y + z
    return (f"Addition : {add}")

print(add_3_variable.__doc__)
print(add_3_variable())
# Out:
# Adding 3 Variables
# Addition : 136

# %%
print(add)
# Out:
# 55

# %% [raw]
# logistic_regression
# knn_classifier
# decision_tree_classifier
# random_forest_classifier

# %%
def logistic_regression():
    print("logistic_regression")
    print("logistic_regression")
    print("logistic_regression")
    print("logistic_regression")
    print("#"*20)

# %%
def knn_classifier():
    print("knn_classifier")
    print("knn_classifier")
    print("knn_classifier")
    print("#"*20)

# %%
def decision_tree_classifier():
    print("decision_tree_classifier")
    print("decision_tree_classifier")
    print("decision_tree_classifier")
    print("#"*20)

# %%
def random_forest_classifier():
    print("random_forest_classifier")
    print("random_forest_classifier")
    print("random_forest_classifier")
    print("#"*20)

# %%
logistic_regression()
knn_classifier()
decision_tree_classifier()
random_forest_classifier()
# Out:
# logistic_regression
# logistic_regression
# logistic_regression
# logistic_regression
# ####################
# knn_classifier
# knn_classifier
# knn_classifier
# ####################
# decision_tree_classifier
# decision_tree_classifier
# decision_tree_classifier
# ####################
# random_forest_classifier
# random_forest_classifier
# random_forest_classifier
# ####################

# %%
a = 10
b = 23
c = 27

print(f"a = {a} b = {b} c = {c} ")
avg = (a+b+c)/3

print(f"Avg is : {avg}")
print("*"*20)
# Out:
# a = 10 b = 23 c = 27
# Avg is : 20.0
# ********************

# %%
def Avg():
    a = int(input("Enter A : "))
    b = int(input("Enter B : "))
    c = int(input("Enter C : "))
    
    avg = (a+b+c)/3
    print(f"Avg of >> {a} , {b} , {c} is : {avg}")
    print("* "*20)

# %%
print(Avg())
# Out:
# Enter A :  22
# Enter B :  1223
# Enter C :  1
# Avg of >> 22 , 1223 , 1 is : 415.3333333333333
# * * * * * * * * * * * * * * * * * * * *
# None

# %%
def Avg(a , b , c):
    print(f"a = {a} , b = {b} ,c = {c}")

    avg = (a+b+c)/3
    print(f"Avg = {avg}")
    print("* "*5)

Avg(112, 32, 78)
Avg(92, 12, 8)
# Out:
# a = 112 , b = 32 ,c = 78
# Avg = 74.0
# * * * * *
# a = 92 , b = 12 ,c = 8
# Avg = 37.333333333333336
# * * * * *

# %%
def Avg(*a):
    avg = sum(a) / len(a)
    return avg

print(Avg(10, 20, 30))
# Out:
# 20.0

# %%
def Avg(*a):
    avg = sum(a)/len(a)
    return avg

Avg(112 , 13 , 90)
# Out:
# 71.66666666666667

# %%
Avg(10 , 33)
# Avg() missing 1 required positional argument: 'c'
# Out:
# 21.5

# %%
Avg(1 , 3, 5, 8)

# Avg() takes 3 positional arguments but 4 were given
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 Avg(1 , 3, 5, 8)
#
# TypeError: Avg() takes 3 positional arguments but 4 were given

# %%
def Avg(a , b , c):     # >>>> Parameters
    """Avg Function : 
            This function is used to find avg of 3 no
            Pass 3 numeric values as positional argument
    """
    print(f"A = {a} , B = {b} , C = {c}")

    avg = (a+b+c)/3
    print(f"Avg = {avg}")
    print()
    print("*  "*5)

Avg(109 , 23 , 45)     # >>>> Arguments
# Out:
# A = 109 , B = 23 , C = 45
# Avg = 59.0
#
# *  *  *  *  *

# %%
print(Avg.__doc__)
# Out:
# Avg Function :
#             This function is used to find avg of 3 no
#             Pass 3 numeric values as positional argument

# %% [markdown]
# ## Factorial

# %%
n = 5
fact = 1

for i in range(1, n+1):
    fact*=i
print(fact)
# Out:
# 120

# %%
n = 5
fact = 1

for i in range(1 , n+1):
    fact *= i

print(fact)
# Out:
# 120

# %%
n = 10
fact = 1

for i in range(1 , n+1):
    fact *= i

print(fact)
# Out:
# 3628800

# %%
n =5
fact = 1

for i in range(1 , n+1):
    if i > 0 :
        fact *= i
        print(f"Iteration {i} >>>> {fact}")
    else:
        print("Not Found")
# Out:
# Iteration 1 >>>> 1
# Iteration 2 >>>> 2
# Iteration 3 >>>> 6
# Iteration 4 >>>> 24
# Iteration 5 >>>> 120

# %%
n = 5
factor = 1

for i in range(1 , n+1):
    factor *= i
print(factor)
# Out:
# 120

# %%
n = 5
fact = 1

for i in range(1 , n+1):
    fact *= i
    
print("Factorial of {} is : {} ".format(n , fact))
# Out:
# Factorial of 5 is : 120

# %%
n = 5
fact = 1
for i in range(1 , n+1):
    fact *= i
    print(f" Iteration {i} Factorial: {fact}")
# Out:
#  Iteration 1 Factorial: 1
#  Iteration 2 Factorial: 2
#  Iteration 3 Factorial: 6
#  Iteration 4 Factorial: 24
#  Iteration 5 Factorial: 120

# %% [raw]
# fact *= i
#
# 1 *= 1 >>>>> 1
# 1 *= 2 >>>>> 2
# 2 *= 3 >>>>> 6
# 6 *= 4 >>>>> 24
# 24 *= 5 >>>>> 120

# %%
n = 5
fact = 1
if n > 0 :
    for i in range(1 , n + 1):
        fact *= i
        
    print("Factorial of <{}> is : <{}>".format(n , fact))
else:
    print("NA")
# Out:
# Factorial of <5> is : <120>

# %%
n = -5 
fact = 1

if n > 0 :
    for i in range(1 , n+1):
        fact*=i
    print("Factorial of {} is : {}".format(n , fact))

else:
    print("Not Available")
# Out:
# Not Available

# %%
n = 7
fact = 1

if n > 0 :
    for i in range(1 , n +1):
        fact *=i
    print("Factorial of {} is : {}".format(n , fact))
else:
    print("NA")
# Out:
# Factorial of 7 is : 5040

# %%
def Factorial():
    n = 8
    fact = 1
    if n > 0 :
        for i in range(1 , n+1):
            fact *= i
        print("Factorial of {} is : {}".format(n , fact))
    else:
        print("NA")

# %%
Factorial()
# Out:
# Factorial of 8 is : 40320

# %%
def factorial(n , fact):
    if n > 0:
        for i in range(1 , n+1):
            fact *= i
        print("Factorial of {} is : {}".format(n , fact))
    else:
        print("Na")

factorial(4 , 1)
# Out:
# Factorial of 4 is : 24

# %%
def factorial(n, fact = 1):
    if n > 0:
        for i in range(1 , n+1):
            fact *= i
        print("Factorial of {} is : {}".format(n , fact))
    else:
        print("Na")

factorial(-5)
# Out:
# Na

# %%
factorial(23)
# Out:
# Factorial of 23 is : 25852016738884976640000

# %%
factorial(7)
# Out:
# Factorial of 7 is : 5040

# %%
def factorial(n, fact = 1):

    """" Finding Factorial of Number"""
    if n > 0:
        for i in range(1 , n+1):
            fact *= i
        print("Factorial of {} is : {}".format(n , fact))
    else:
        print("Na")

factorial(-5)
print(factorial.__doc__)
# Out:
# Na
# " Finding Factorial of Number

# %%
def get_sum(iterable):
    total = 0
    for i in iterable:
        total += i
    return total

get_sum([1, 2, 3, 4, 5])
# Out:
# 15

# %% [raw]
# Total = 0
# itr 1 >>> 0 + 1 = 1
# itr 2 >>> 1 + 2 = 3
# itr 3 >>> 3 + 3 = 6
# itr 4 >>> 6 + 4 = 10
# itr 5 >>> 10 + 5 = 15

# %%
a = int(input("Enter Your Age")) 

def greet():
    print("Hello")
def Leave():
    print("Please Leave")

if a >= 18:
    print(greet())
        
else:
    print(Leave())
    pass
# Out:
# Enter Your Age 1
# Please Leave
# None

# %%
for i in range(1 , 5 + 1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
