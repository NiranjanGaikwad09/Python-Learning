# %% [markdown]
# # OS Module

# %% [markdown]
# OS > Operating System

# %%
import os

# %% [markdown]
# ## OS Modlule Functions

# %% [raw]
# 1. os.rename()                 > Renames file / Moves file
# 2. os.remove()                 > To remove the files
# 3. os.path.exists()            > To check file or folder
# 4. mkdir() > To create a folder
# 5. os.makedirs()               > To create multiple folder in tress structure (Folder inside folder)
# 6. os.rmdir()                  > To Delete emplty Directory
# 7. shutil.rmtree(Folder_Path)  > Delete nonempty Dir
# 8. os.listdir(folder path)     > Checks file/folder
# 9. os.getcwd()                 > Checks current path
# 10. os.path.join(path1, path2)     > To join multiple paths
# 11. shutil.copy (sourcepath, destination path)      > Make another copy

# %% [markdown]
# # 1. Rename / Move

# %% [markdown]
# os.rename(source_file_path , destination_file_path)

# %%
os.rename('deeplearning.txt' , 'Data_Science.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 os.rename('deeplearning.txt' , 'Data_Science.txt')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'deeplearning.txt' -> 'Data_Science.txt'
